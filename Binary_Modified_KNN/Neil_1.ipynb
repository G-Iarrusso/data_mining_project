# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
data = pd.read_csv('../Data/Players_15.csv')
training_data = data.drop(['Player', 'School', 'Pos', "Shuttle", "Broad_Jump", "Vertical"], axis=1)
training_data = training_data.dropna()
cond = training_data['Draft_Pick'] == -1
training_data.loc[cond,'Draft_Pick'] = 'Not Drafted'
cond = training_data['Draft_Pick'] != 'Not Drafted'
training_data.loc[cond,'Draft_Pick'] = 'Drafted'
training_data
# Out:
#         Ht     Wt  Bench  Broad_Jump  3Cone   Draft_Pick
# 0     76.0  334.0   23.0        94.0   8.48      Drafted
# 1     78.0  312.0   20.0        96.0   7.72      Drafted
# 3     76.0  302.0   17.0       103.0   7.76      Drafted
# 4     77.0  297.0   28.0       100.0   7.82      Drafted
# 5     79.0  304.0   28.0       103.0   7.65      Drafted
# ...    ...    ...    ...         ...    ...          ...
# 1188  76.0  308.0   36.0       106.0   7.67      Drafted
# 1189  78.0  306.0   23.0       105.0   7.67  Not Drafted
# 1191  78.0  310.0   34.0       108.0   7.70      Drafted
# 1192  75.0  306.0   24.0       105.0   7.75  Not Drafted
# 1193  76.0  311.0   27.0       106.0   7.77      Drafted
#
# [741 rows x 6 columns]

# %%
training_features = training_data.drop(['Draft_Pick'], axis=1)
training_target = training_data['Draft_Pick']

# %%
x_train, x_test, y_train, y_test = train_test_split(training_features, training_target, test_size=0.1, random_state=101)

# %%
scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

classifier = KNeighborsClassifier(n_neighbors=25)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Drafted       0.72      0.94      0.82        54
#  Not Drafted       0.25      0.05      0.08        21
#
#     accuracy                           0.69        75
#    macro avg       0.48      0.50      0.45        75
# weighted avg       0.59      0.69      0.61        75
